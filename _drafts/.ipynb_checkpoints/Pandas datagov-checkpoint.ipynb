# %%
import pandas # importando as bibliotecas
import numpy 
import matplotlib 
import ggplot

dados = pandas.read_csv("USAID_2014_Commuter_Survey_Data.csv") #importando o csv

# %%
dados.head(10)
# Out:
#   User Code 1 Please select your operating administration or office:  \
# 0  01A1EJ9V         U.S. Agency for International Development
# 1  01TOQN5I         U.S. Agency for International Development
# 2  02BLP4WU         U.S. Agency for International Development
# 3  0407RZXE         U.S. Agency for International Development
# 4  06EWZXIN         U.S. Agency for International Development
# 5  096ODJ8X         U.S. Agency for International Development
# 6  0AXW6GWP         U.S. Agency for International Development
# 7  0B8TXXZF         U.S. Agency for International Development
# 8  0BGM8DL0         U.S. Agency for International Development
# 9  0D3CACJG         U.S. Agency for International Development
#
#   2 Begin typing your work zip code and select your work site from the list that will appear below.  If your site does not appear in the list select 'Site not found'.  If you telework 100% of the time please select the site to which you officially report.  \
# ...

# %%
dados.describe()
# Out:
#        4 How did you travel TO WORK each day during a TYPICAL week?  If you select 'N/A' for transportation method select 'N/A' for # Miles.  \
# count                                                  0
# mean                                                 NaN
# std                                                  NaN
# min                                                  NaN
# 25%                                                  NaN
# 50%                                                  NaN
# 75%                                                  NaN
# max                                                  NaN
#
#        7 How did you travel FROM WORK each day during a TYPICAL week?  If you select 'N/A' for transportation method select 'N/A' for # Miles.  \
# count                                                  0
# mean                                                 NaN
# std                                                  NaN
# ...
